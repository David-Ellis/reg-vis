# %% [markdown]
# # Example code for using reg-vis

# %% [markdown]
# ## Loading data

# %%
import sys
sys.path.append('..')
import reg_vis

# Initiate plotting class
reg_vis = reg_vis.reg_plot()

# Load data
reg_vis.load_data("example_data.xlsx")

# %% [markdown]
# You can equally load the data into a pandas dataframe yourself and then use `reg_vis.df = data`.

# %% [markdown]
# ## Basic plotting

# %%
# Choose font sizes
reg_vis.font_size = 10
reg_vis.group_size = 10.5
reg_vis.header_size = 11

# Plot regression data
reg_vis.plot()

# Save visualisation
reg_vis.save_plot("example_plot1.png")

# %% [markdown]
# ## Variable counts

# %% [markdown]
# You can also include the number of cases for each variable by setting `counts = True` in the `.plot()` function.

# %%
# Choose font sizes
reg_vis.font_size = 10
reg_vis.group_size = 10.5
reg_vis.header_size = 11

# Plot regression data
reg_vis.plot(counts = True)

# Save visualisation
reg_vis.save_plot("example_plot2.png")

# %% [markdown]
# ## Adding colour
#
# We can also add background colour to the column headers and the different variable groups as follows

# %%
reg_vis.plot(counts = True, 
             group1_color = None,
             group2_color = "yellow",
             group_alpha = 0.15,
             head_fill = "gray")

reg_vis.save_plot("example_plot3.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c1209fde9c3c> in <module>
# ----> 1 reg_vis.plot(counts = True,
#       2              group1_color = None,
#       3              group2_color = "tab:yellow",
#       4              group_alpha = 0.15,
#       5              head_fill = "gray")
#
# ~\Desktop\hide\work\reg-vis\reg_vis.py in plot(self, counts, group1_color, group2_color, group_alpha, head_fill, head_alpha)
#     252                         color_ax.append(ax4)
#     253                     for ax in color_ax:
# --> 254                         ax.fill_between([-10, 20],
#     255                                          [boundary[0]+0.5,boundary[0]+0.5],
#     256                                          [boundary[1]+0.5,boundary[1]+0.5],
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5384     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5385                      step=None, **kwargs):
# -> 5386         return self._fill_between_x_or_y(
#    5387             "x", x, y1, y2,
#    5388             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5370             polys.append(pts)
#    5371
# -> 5372         collection = mcoll.PolyCollection(polys, **kwargs)
#    5373
#    5374         # now update the datalim and autoscale
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1204             Forwarded to `.Collection`.
#    1205         """
# -> 1206         super().__init__(**kwargs)
#    1207         self.set_sizes(sizes)
#    1208         self.set_verts(verts, closed)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     215
#     216         self._path_effects = None
# --> 217         self.update(kwargs)
#     218         self._paths = None
#     219
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\artist.py in update(self, props)
#    1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
# -> 1064                     ret.append(func(v))
#    1065         if ret:
#    1066             self.pchanged()
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\collections.py in set_color(self, c)
#     758             For setting the edge or face color individually.
#     759         """
# --> 760         self.set_facecolor(c)
#     761         self.set_edgecolor(c)
#     762
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\collections.py in set_facecolor(self, c)
#     787             c = c.lower()
#     788         self._original_facecolor = c
# --> 789         self._set_facecolor(c)
#     790
#     791     def get_facecolor(self):
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\collections.py in _set_facecolor(self, c)
#     769             c = self._get_default_facecolor()
#     770
# --> 771         self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     772         self.stale = True
#     773
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     365
#     366     if isinstance(c, str):
# --> 367         raise ValueError("Using a string of single character colors as "
#     368                          "a color sequence is not supported. The colors can "
#     369                          "be passed as an explicit list instead.")
#
# ValueError: Using a string of single character colors as a color sequence is not supported. The colors can be passed as an explicit list instead.
